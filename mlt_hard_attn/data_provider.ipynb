# %%
import os
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
% matplotlib inline  
from PIL import Image
import cv2

# %%
class MLTData():
    def __init__(self, batch_size=32, image_size=128, orig_image_size=[480, 640], train_proportion=1):
        self.name = 'mlt'
        self.img_dir = '/media/yi/DATA/data-orig/MLT/image'
        self.box_dir = '/home/yi/code/few_shot/mlt/box'
        self.meta = self.get_meta(self.img_dir, self.box_dir)
 
        self.train_meta = self.assign_meta('train')
        self.test_meta = self.assign_meta('test')
        
        self.batch_size = batch_size
        self.im_size = image_size
        self.orig_im_size = orig_image_size
        self.train_proportion = train_proportion
        num_image = len(self.train_meta['img'])
        self.train_meta['img'] = self.train_meta['img'][0:int(num_image * train_proportion)]
        self.train_meta['box'] = self.train_meta['box'][0:int(num_image * train_proportion)]
        print len(self.train_meta['img'])
        self.train_idx = np.random.permutation(len(self.train_meta['img']))
        self.train_cnt = 0
        self.test_idx = np.random.permutation(len(self.test_meta['img']))
        self.test_cnt = 0
        
        print len(self.train_meta['img'])
        print len(self.train_meta['box'])
        print len(self.train_idx)
        print len(self.test_meta['img'])
        print len(self.test_meta['box'])
        self.compute_statistics('train')
        self.compute_statistics('test')
        
        self.class_map = {3:0, 4:1, 5:2, 6:3, 13:4, 24:5}
        
    def get_meta(self, img_dir, box_dir):
        meta = {}
        meta['img'], meta['box'] = [], []
        for sub_dir in os.listdir(box_dir):
            box_files = os.listdir(os.path.join(box_dir, sub_dir))
            box_files.sort(key=lambda f: int(filter(str.isdigit, f)))
            box_file_names = [os.path.join(box_dir, sub_dir, f) for f in box_files]
            img_files = []
            for f in box_files:
                file_name, file_ext = os.path.splitext(f)
                img_files.append(file_name + '_color.jpg')
            img_file_names = [os.path.join(img_dir, sub_dir, f) for f in img_files]
            meta['img'].extend(img_file_names)
            meta['box'].extend(box_file_names)
        print meta['img'][0:10], meta['box'][0:10], len(meta['img']), len(meta['box'])
        return meta
    
    def assign_meta(self, status='train'):
        num_image = len(self.meta['img'])
        if status == 'train':
            meta = {}
            meta['img'] = self.meta['img'][0:int(num_image * 0.9)]
            meta['box'] = self.meta['box'][0:int(num_image * 0.9)]
        else:
            meta = {}
            meta['img'] = self.meta['img'][int(num_image * 0.9):]
            meta['box'] = self.meta['box'][int(num_image * 0.9):]
        return meta
    
    def compute_statistics(self, status='train'):
        if status == 'train':
            box_meta = self.train_meta['box']
        else:
            box_meta = self.test_meta['box']
        box = []
        for box_file_name in box_meta:
            with open(box_file_name) as txt_file:
                box_info = txt_file.readlines()
            for row in box_info:
                row = row.strip().split(' ')
                box.append(row)
        box = np.array(box).astype(np.int)

        cls = box[:, 4]
        box = box[:, 0:4]
        cls_labels = set(list(cls))
        count = dict()
        max_count = 0
        total_count = 0
        for cls_label in cls_labels:
            count[cls_label] = (cls == cls_label).sum()
            if count[cls_label] > max_count:
                max_count = count[cls_label]
            total_count = total_count + count[cls_label]
        print(status)
        print(count)
        print(max_count * 1.0 / total_count)

    def get_next_batch(self, status='train'):
        batch_size, im_size, orig_im_size = self.batch_size, self.im_size, self.orig_im_size
        im = np.zeros((batch_size, im_size, im_size, 3))
        im_big = np.zeros((batch_size, orig_im_size[0], orig_im_size[1], 3))
        boxes = np.zeros((batch_size, 4))
        label = np.zeros(batch_size)
        i = 0
        while i < batch_size:
            if status == 'train':
                image_name = self.train_meta['img'][self.train_idx[self.train_cnt]]
                box_name = self.train_meta['box'][self.train_idx[self.train_cnt]]
                print image_name
                print box_name
            else:
                image_name = self.test_meta['img'][self.test_idx[self.test_cnt]]
                box_name = self.test_meta['box'][self.test_idx[self.test_cnt]]
            image = np.array(Image.open(image_name))
            # image = cv2.imread(image_name)
            # clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
            # image[:, :, 0] = clahe.apply(image[:, :, 0])
            # image[:, :, 1] = clahe.apply(image[:, :, 1])
            # image[:, :, 2] = clahe.apply(image[:, :, 2])
            image = image / 255.0
            box = []
            with open(box_name) as txt_file:
                box_info = txt_file.readlines()
            for row in box_info:
                row = row.strip().split(' ')
                box.append(row)
            box = np.array(box).astype(np.int)
            
            if status == 'train':
                self.train_cnt = self.train_cnt + 1
                if self.train_cnt >= len(self.train_meta['img']):
                    self.train_idx = np.random.permutation(len(self.train_meta['img']))
                    self.train_cnt = 0
            else:
                self.test_cnt = self.test_cnt + 1
                if self.test_cnt >= len(self.test_meta['img']):
                    self.test_idx = np.random.permutation(len(self.test_meta['img']))
                    self.test_cnt = 0
            
            for n in range(box.shape[0]):
                cls = box[n, 4]
                bb = box[n, 0:4]
                # crop_im, bb = self.crop_image(image, bb, im_size, big_im_size)
                # im_big[i, :, :, :] = crop_im
                # im[i, :, :, :] = cv2.resize(crop_im, (im_size, im_size), interpolation=cv2.INTER_AREA)
                im_big[i, :, :, :] = image
                im[i, :, :, :] = cv2.resize(image, (im_size, im_size), interpolation=cv2.INTER_AREA)
                boxes[i, :] = bb
                label[i] = self.class_map[cls]
                i = i + 1
                if i >= batch_size:
                    break
        im = im.transpose((0, 3, 1, 2))
        im_big = im_big.transpose((0, 3, 1, 2))
        return im, im_big, boxes, label
    
    # def crop_image(self, image, bb, im_size, big_im_size):
    #     im_height, im_width = image.shape[0], image.shape[1]
    #     x_c, y_c = (bb[0] + bb[2]) / 2, (bb[1] + bb[3]) / 2
    #     width, height = bb[2] - bb[0], bb[3] - bb[1]
    #     
    #     max_crop_height = height / im_size * big_im_size
    #     max_crop_width = width / im_size * big_im_size
    #     max_crop_height = min(im_height, max_crop_height)
    #     max_crop_width = min(im_width, max_crop_width)
    #     min_crop_height = max(height, big_im_size)
    #     min_crop_width = max(width, big_im_size)
    #     
    #     crop_height = np.random.randint(min_crop_height, max_crop_height)
    #     crop_width = np.random.randint(min_crop_width, max_crop_width)
    #     
    #     y_s_min = min(bb[3] - crop_height, bb[1])
    #     y_s_min = max(y_s_min, 0)
    #     y_s_max = max(bb[3], bb[1] + crop_height)
    #     y_s_max = min(y_s_max, im_height)
    #     x_s_min = min(bb[2] - crop_width, bb[0])
    #     x_s_min = max(x_s_min, 0)
    #     x_s_max = max(bb[2], bb[0] + crop_width)
    #     x_s_max = min(x_s_max, im_width)
    #     
    #     y_s = np.random.randint(y_s_min, y_s_max)
    #     x_s = np.random.randint(x_s_min, x_s_max)
    #     crop_im = image[y_s:y_e, x_s:x_e, :]
    #     
    #     im[i, :, :, :] = cv2.resize(crop_im, (big_im_size, big_im_size), interpolation=cv2.INTER_AREA)
    #     return im, im_big, new_box
    
    def display(self, im, im_big, box, label):
        im = im[0, :, :, :].transpose(1, 2, 0)
        
        fig,ax = plt.subplots(1)
        ax.imshow(im)
        
        im_big = im_big[0, :, :, :].transpose(1, 2, 0)
        
        fig,ax = plt.subplots(1)
        ax.imshow(im_big)
        
        a = box[0, 0:4]
        box_area = (a[2] - a[0]) * (a[3] - a[1])
        box_size = np.sqrt((a[2] - a[0]) * (a[3] - a[1]))
        print(box_area)
        print(box_size)
        rect = patches.Rectangle((a[0], a[1]),a[2]-a[0],a[3]-a[1],linewidth=2,edgecolor='g',facecolor='none')

        # Add the patch to the Axes
        ax.add_patch(rect)
        
        plt.show()
        
        # print(img)
        print(label[0])

# %%
batch_size = 32
image_size = 128
orig_image_size = [480, 640]
train_proportion = 1
data = MLTData(batch_size, image_size, orig_image_size, train_proportion)
im, im_big, box, label = data.get_next_batch('train')
data.display(im, im_big, box, label)
im, im_big, box, label = data.get_next_batch('test')
data.display(im, im_big, box, label)
# Out:
# ['/media/yi/DATA/data-orig/MLT/image/b626b9709289bde3a6b3504b7f5586f4/000000_color.jpg', '/media/yi/DATA/data-orig/MLT/image/b626b9709289bde3a6b3504b7f5586f4/000001_color.jpg', '/media/yi/DATA/data-orig/MLT/image/b626b9709289bde3a6b3504b7f5586f4/000002_color.jpg', '/media/yi/DATA/data-orig/MLT/image/b626b9709289bde3a6b3504b7f5586f4/000003_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000001_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000002_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000003_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000004_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000005_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000006_color.jpg'] ['/home/yi/code/few_shot/mlt/box/b626b9709289bde3a6b3504b7f5586f4/000000.txt', '/home/yi/code/few_shot/mlt/box/b626b9709289bde3a6b3504b7f5586f4/000001.txt', '/home/yi/code/few_shot/mlt/box/b626b9709289bde3a6b3504b7f5586f4/000002.txt', '/home/yi/code/few_shot/mlt/box/b626b9709289bde3a6b3504b7f5586f4/000003.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000001.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000002.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000003.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000004.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000005.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000006.txt'] 7770 7770
# 6993
# 6993
# 6993
# 6993
# 777
# 777
# train
# {3: 2219, 4: 3405, 5: 2356, 6: 2147, 13: 1678, 24: 1070}
# 0.2644660194174757
# test
# {3: 264, 4: 425, 5: 271, 6: 216, 13: 150, 24: 111}
# 0.29575504523312457
# /media/yi/DATA/data-orig/MLT/image/08ed0ea60357e04681963c29a340b79a/000015_color.jpg
# /home/yi/code/few_shot/mlt/box/08ed0ea60357e04681963c29a340b79a/000015.txt
# /media/yi/DATA/data-orig/MLT/image/e547f88d34111048357bb3cb627028fc/000012_color.jpg
# /home/yi/code/few_shot/mlt/box/e547f88d34111048357bb3cb627028fc/000012.txt
# /media/yi/DATA/data-orig/MLT/image/b62bc428b445ee73b302fc035e7781c4/000019_color.jpg
# /home/yi/code/few_shot/mlt/box/b62bc428b445ee73b302fc035e7781c4/000019.txt
# /media/yi/DATA/data-orig/MLT/image/b099a0660d475b34bb6171a1ff003af5/000020_color.jpg
# /home/yi/code/few_shot/mlt/box/b099a0660d475b34bb6171a1ff003af5/000020.txt
# /media/yi/DATA/data-orig/MLT/image/47064ac8115c4a4446c7d74c6aadadef/000002_color.jpg
# /home/yi/code/few_shot/mlt/box/47064ac8115c4a4446c7d74c6aadadef/000002.txt
# /media/yi/DATA/data-orig/MLT/image/79a519f56150bba2f0083f51bb1acdfb/000010_color.jpg
# /home/yi/code/few_shot/mlt/box/79a519f56150bba2f0083f51bb1acdfb/000010.txt
# /media/yi/DATA/data-orig/MLT/image/246585773a2de66bed1a3caa0e6da37c/000028_color.jpg
# /home/yi/code/few_shot/mlt/box/246585773a2de66bed1a3caa0e6da37c/000028.txt
# /media/yi/DATA/data-orig/MLT/image/2ca31473494167f2b2bbb417b75773a6/000011_color.jpg
# /home/yi/code/few_shot/mlt/box/2ca31473494167f2b2bbb417b75773a6/000011.txt
# /media/yi/DATA/data-orig/MLT/image/ea35885f5ac1c63b6d5b42aa66123d10/000008_color.jpg
# /home/yi/code/few_shot/mlt/box/ea35885f5ac1c63b6d5b42aa66123d10/000008.txt
# /media/yi/DATA/data-orig/MLT/image/14a10c1dd3b9e580b4d545c76c8d49af/000007_color.jpg
# /home/yi/code/few_shot/mlt/box/14a10c1dd3b9e580b4d545c76c8d49af/000007.txt
# /media/yi/DATA/data-orig/MLT/image/39379395b75285f4a69436861ed81d9c/000011_color.jpg
# /home/yi/code/few_shot/mlt/box/39379395b75285f4a69436861ed81d9c/000011.txt
# /media/yi/DATA/data-orig/MLT/image/a880a1db2d7cbff2266c5740a374703e/000013_color.jpg
# /home/yi/code/few_shot/mlt/box/a880a1db2d7cbff2266c5740a374703e/000013.txt
# /media/yi/DATA/data-orig/MLT/image/9d56de9b778d3c39e23973c0036875a6/000008_color.jpg
# /home/yi/code/few_shot/mlt/box/9d56de9b778d3c39e23973c0036875a6/000008.txt
# /media/yi/DATA/data-orig/MLT/image/cfe4615a8fd47d5bba88ee3bbbfa8fc1/000000_color.jpg
# /home/yi/code/few_shot/mlt/box/cfe4615a8fd47d5bba88ee3bbbfa8fc1/000000.txt
# /media/yi/DATA/data-orig/MLT/image/e09114fc4b3bd44ce6f938f71004b938/000035_color.jpg
# /home/yi/code/few_shot/mlt/box/e09114fc4b3bd44ce6f938f71004b938/000035.txt
# /media/yi/DATA/data-orig/MLT/image/470ec7cc6f1bab7fe42b7b39c073b228/000026_color.jpg
# /home/yi/code/few_shot/mlt/box/470ec7cc6f1bab7fe42b7b39c073b228/000026.txt
# /media/yi/DATA/data-orig/MLT/image/04377407a456d8b726d5b161e1f023ac/000008_color.jpg
# /home/yi/code/few_shot/mlt/box/04377407a456d8b726d5b161e1f023ac/000008.txt
# /media/yi/DATA/data-orig/MLT/image/7e4a6228dfbc0ec7f9b987a7fe6ee434/000015_color.jpg
# /home/yi/code/few_shot/mlt/box/7e4a6228dfbc0ec7f9b987a7fe6ee434/000015.txt
# 68894.0
# 262.4766656295374
# 2.0
# 20124.0
# 141.85908501044267
# 0.0
