# %%
import os
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
% matplotlib inline  
from PIL import Image
import cv2

# %%
class MLTData3D():
    def __init__(self, batch_size=32, image_size=128, align_object=True, train_proportion=1):
        self.name = 'mlt'
        self.img_dir = '/media/yi/DATA/data-orig/MLT/image'
        self.box_dir = '/home/yi/code/few_shot/mlt/box'
        self.depth_dir = '/media/yi/DATA/data-orig/MLT/depth'
        self.meta = self.get_meta(self.img_dir, self.box_dir, self.depth_dir)
 
        self.train_meta = self.assign_meta('train')
        self.test_meta = self.assign_meta('test')
        
        self.batch_size = batch_size
        self.im_size = image_size
        self.align_object= align_object
        self.train_proportion = train_proportion
        num_image = len(self.train_meta['img'])
        self.train_meta['img'] = self.train_meta['img'][0:int(num_image * train_proportion)]
        self.train_meta['box'] = self.train_meta['box'][0:int(num_image * train_proportion)]
        self.train_meta['depth'] = self.train_meta['depth'][0:int(num_image * train_proportion)]
        print len(self.train_meta['img'])
        self.train_idx = np.random.permutation(len(self.train_meta['img']))
        self.train_cnt = 0
        self.test_idx = np.random.permutation(len(self.test_meta['img']))
        self.test_cnt = 0
        
        print len(self.train_meta['img'])
        print len(self.train_meta['box'])
        print len(self.train_meta['depth'])
        print len(self.train_idx)
        print len(self.test_meta['img'])
        print len(self.test_meta['box'])
        print len(self.test_meta['depth'])
        self.compute_statistics('train')
        self.compute_statistics('test')
        
        self.class_map = {3:0, 4:1, 5:2, 6:3, 13:4, 24:5}
        
    def get_meta(self, img_dir, box_dir, depth_dir):
        meta = {}
        meta['img'], meta['box'], meta['depth'] = [], [], []
        for sub_dir in os.listdir(box_dir):
            box_files = os.listdir(os.path.join(box_dir, sub_dir))
            box_files.sort(key=lambda f: int(filter(str.isdigit, f)))
            box_file_names = [os.path.join(box_dir, sub_dir, f) for f in box_files]
            img_files, depth_files = [], []
            for f in box_files:
                file_name, file_ext = os.path.splitext(f)
                img_files.append(file_name + '_color.jpg')
                depth_files.append(file_name + '_depth.png')
            img_file_names = [os.path.join(img_dir, sub_dir, f) for f in img_files]
            depth_file_names = [os.path.join(depth_dir, sub_dir, f) for f in depth_files]
            meta['img'].extend(img_file_names)
            meta['box'].extend(box_file_names)
            meta['depth'].extend(depth_file_names)
        print meta['img'][0:10], meta['box'][0:10], meta['depth'][0:10], len(meta['img']), len(meta['box']), len(meta['depth'])
        return meta
    
    def assign_meta(self, status='train'):
        num_image = len(self.meta['img'])
        if status == 'train':
            meta = {}
            meta['img'] = self.meta['img'][0:int(num_image * 0.9)]
            meta['box'] = self.meta['box'][0:int(num_image * 0.9)]
            meta['depth'] = self.meta['depth'][0:int(num_image * 0.9)]
        else:
            meta = {}
            meta['img'] = self.meta['img'][int(num_image * 0.9):]
            meta['box'] = self.meta['box'][int(num_image * 0.9):]
            meta['depth'] = self.meta['depth'][int(num_image * 0.9):]
        return meta
    
    def compute_statistics(self, status='train'):
        if status == 'train':
            box_meta = self.train_meta['box']
        else:
            box_meta = self.test_meta['box']
        box = []
        for box_file_name in box_meta:
            with open(box_file_name) as txt_file:
                box_info = txt_file.readlines()
            for row in box_info:
                row = row.strip().split(' ')
                box.append(row)
        box = np.array(box).astype(np.int)

        cls = box[:, 4]
        box = box[:, 0:4]
        cls_labels = set(list(cls))
        count = dict()
        max_count = 0
        total_count = 0
        for cls_label in cls_labels:
            count[cls_label] = (cls == cls_label).sum()
            if count[cls_label] > max_count:
                max_count = count[cls_label]
            total_count = total_count + count[cls_label]
        print(status)
        print(count)
        print(max_count * 1.0 / total_count)

    def get_next_batch(self, status='train'):
        batch_size, im_size = self.batch_size, self.im_size
        im = np.zeros((batch_size, im_size, im_size, 3))
        dp = np.zeros((batch_size, im_size, im_size, 1))
        label = np.zeros(batch_size)
        i = 0
        while i < batch_size:
            if status == 'train':
                image_name = self.train_meta['img'][self.train_idx[self.train_cnt]]
                box_name = self.train_meta['box'][self.train_idx[self.train_cnt]]
                depth_name = self.train_meta['depth'][self.train_idx[self.train_cnt]]
                print image_name
                print box_name
                print depth_name
            else:
                image_name = self.test_meta['img'][self.test_idx[self.test_cnt]]
                box_name = self.test_meta['box'][self.test_idx[self.test_cnt]]
                depth_name = self.test_meta['depth'][self.test_idx[self.test_cnt]]
            image = np.array(Image.open(image_name))
            # image = cv2.imread(image_name)
            # clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
            # image[:, :, 0] = clahe.apply(image[:, :, 0])
            # image[:, :, 1] = clahe.apply(image[:, :, 1])
            # image[:, :, 2] = clahe.apply(image[:, :, 2])
            image = image / 255.0
            box = []
            with open(box_name) as txt_file:
                box_info = txt_file.readlines()
            for row in box_info:
                row = row.strip().split(' ')
                box.append(row)
            box = np.array(box).astype(np.int)
            depth = np.array(Image.open(depth_name))
            depth = depth / 5000.0
            
            if status == 'train':
                self.train_cnt = self.train_cnt + 1
                if self.train_cnt >= len(self.train_meta['img']):
                    self.train_idx = np.random.permutation(len(self.train_meta['img']))
                    self.train_cnt = 0
            else:
                self.test_cnt = self.test_cnt + 1
                if self.test_cnt >= len(self.test_meta['img']):
                    self.test_idx = np.random.permutation(len(self.test_meta['img']))
                    self.test_cnt = 0
            
            for n in range(box.shape[0]):
                cls = box[n, 4]
                bb = box[n, 0:4]
                crop_im, crop_depth = self.crop_image(image, depth, bb, im_size)
                im[i, :, :, :] = cv2.resize(crop_im, (im_size, im_size), interpolation=cv2.INTER_AREA)
                print np.max(crop_depth)
                dp[i, :, :, 0] = cv2.resize(crop_depth, (im_size, im_size), interpolation=cv2.INTER_AREA)
                print np.max(dp[i, :, :, 0])
                label[i] = self.class_map[cls]
                i = i + 1
                if i >= batch_size:
                    break
        im = im.transpose((0, 3, 1, 2))
        dp = dp.transpose((0, 3, 1, 2))
        return im, dp, label
    
    def crop_image(self, image, depth, bb, im_size):
        im_height, im_width = image.shape[0], image.shape[1]
        x_c, y_c = (bb[0] + bb[2]) / 2, (bb[1] + bb[3]) / 2
        width, height = bb[2] - bb[0], bb[3] - bb[1]
        if self.align_object:
            height = height * 2
            width = width * 2
        else:
            height = np.random.randint(height * 2, height * 5)
            width = np.random.randint(width * 2, width * 5)
            
        y_s = max(0, y_c - height / 2)
        y_e = min(im_height, y_c + height / 2)
        x_s = max(0, x_c - width / 2)
        x_e = min(im_width, x_c + width / 2)
        im = image[y_s:y_e, x_s:x_e, :]
        dp = depth[y_s:y_e, x_s:x_e]
        return im, dp
    
    def display(self, im, depth, label):
        img = im[0, :, :, :].transpose(1, 2, 0)
        depth = depth[0, 0, :, :]
        
        plt.figure()
        plt.imshow(img)
        plt.axis('off')
        plt.figure()
        plt.imshow(depth)
        plt.axis('off')
        plt.show()
        
        # print(img)
        print(label[0])

# %%
batch_size = 32
image_size = 128
align_object = True
train_proportion = 1
data = MLTData3D(batch_size, image_size, align_object, train_proportion)
data.align_object = True
im, depth, label = data.get_next_batch('train')
data.display(im, depth, label)
im, depth, label = data.get_next_batch('test')
data.display(im, depth, label)
# Out:
# ['/media/yi/DATA/data-orig/MLT/image/b626b9709289bde3a6b3504b7f5586f4/000000_color.jpg', '/media/yi/DATA/data-orig/MLT/image/b626b9709289bde3a6b3504b7f5586f4/000001_color.jpg', '/media/yi/DATA/data-orig/MLT/image/b626b9709289bde3a6b3504b7f5586f4/000002_color.jpg', '/media/yi/DATA/data-orig/MLT/image/b626b9709289bde3a6b3504b7f5586f4/000003_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000001_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000002_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000003_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000004_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000005_color.jpg', '/media/yi/DATA/data-orig/MLT/image/294180c01ac27217d287a81a0f5b8dd4/000006_color.jpg'] ['/home/yi/code/few_shot/mlt/box/b626b9709289bde3a6b3504b7f5586f4/000000.txt', '/home/yi/code/few_shot/mlt/box/b626b9709289bde3a6b3504b7f5586f4/000001.txt', '/home/yi/code/few_shot/mlt/box/b626b9709289bde3a6b3504b7f5586f4/000002.txt', '/home/yi/code/few_shot/mlt/box/b626b9709289bde3a6b3504b7f5586f4/000003.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000001.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000002.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000003.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000004.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000005.txt', '/home/yi/code/few_shot/mlt/box/294180c01ac27217d287a81a0f5b8dd4/000006.txt'] ['/media/yi/DATA/data-orig/MLT/depth/b626b9709289bde3a6b3504b7f5586f4/000000_depth.png', '/media/yi/DATA/data-orig/MLT/depth/b626b9709289bde3a6b3504b7f5586f4/000001_depth.png', '/media/yi/DATA/data-orig/MLT/depth/b626b9709289bde3a6b3504b7f5586f4/000002_depth.png', '/media/yi/DATA/data-orig/MLT/depth/b626b9709289bde3a6b3504b7f5586f4/000003_depth.png', '/media/yi/DATA/data-orig/MLT/depth/294180c01ac27217d287a81a0f5b8dd4/000001_depth.png', '/media/yi/DATA/data-orig/MLT/depth/294180c01ac27217d287a81a0f5b8dd4/000002_depth.png', '/media/yi/DATA/data-orig/MLT/depth/294180c01ac27217d287a81a0f5b8dd4/000003_depth.png', '/media/yi/DATA/data-orig/MLT/depth/294180c01ac27217d287a81a0f5b8dd4/000004_depth.png', '/media/yi/DATA/data-orig/MLT/depth/294180c01ac27217d287a81a0f5b8dd4/000005_depth.png', '/media/yi/DATA/data-orig/MLT/depth/294180c01ac27217d287a81a0f5b8dd4/000006_depth.png'] 7770 7770 7770
# 6993
# 6993
# 6993
# 6993
# 6993
# 777
# 777
# 777
# train
# {3: 2219, 4: 3405, 5: 2356, 6: 2147, 13: 1678, 24: 1070}
# 0.2644660194174757
# test
# {3: 264, 4: 425, 5: 271, 6: 216, 13: 150, 24: 111}
# 0.29575504523312457
# /media/yi/DATA/data-orig/MLT/image/c4249b7401e01eeac19594307cd5fbb4/000000_color.jpg
# /home/yi/code/few_shot/mlt/box/c4249b7401e01eeac19594307cd5fbb4/000000.txt
# /media/yi/DATA/data-orig/MLT/depth/c4249b7401e01eeac19594307cd5fbb4/000000_depth.png
# 0.9052
# 0.9032597405212549
# 0.9052
# 0.9030609333596102
# 0.5286
# 0.5270151100818841
# /media/yi/DATA/data-orig/MLT/image/ea2231496c61d3a1324683d54d379cf3/000008_color.jpg
# /home/yi/code/few_shot/mlt/box/ea2231496c61d3a1324683d54d379cf3/000008.txt
# /media/yi/DATA/data-orig/MLT/depth/ea2231496c61d3a1324683d54d379cf3/000008_depth.png
# 0.759
# 0.7563440338078742
# /media/yi/DATA/data-orig/MLT/image/5ca8fee44f8e7c314947e185b0fcabbf/000018_color.jpg
# /home/yi/code/few_shot/mlt/box/5ca8fee44f8e7c314947e185b0fcabbf/000018.txt
# /media/yi/DATA/data-orig/MLT/depth/5ca8fee44f8e7c314947e185b0fcabbf/000018_depth.png
# 0.8956
# 0.8923243015530634
# /media/yi/DATA/data-orig/MLT/image/75eaa4698d40184ca38a16fa4618ef11/000006_color.jpg
# /home/yi/code/few_shot/mlt/box/75eaa4698d40184ca38a16fa4618ef11/000006.txt
# /media/yi/DATA/data-orig/MLT/depth/75eaa4698d40184ca38a16fa4618ef11/000006_depth.png
# 0.9642
# 0.9613617487383148
# /media/yi/DATA/data-orig/MLT/image/83795ace42377967c1a1d07b1f5ff104/000005_color.jpg
# /home/yi/code/few_shot/mlt/box/83795ace42377967c1a1d07b1f5ff104/000005.txt
# /media/yi/DATA/data-orig/MLT/depth/83795ace42377967c1a1d07b1f5ff104/000005_depth.png
# 1.3074
# 1.301569649718712
# 1.4142
# 1.402216628347883
# 0.7726
# 0.769763600657766
# /media/yi/DATA/data-orig/MLT/image/14a10c1dd3b9e580b4d545c76c8d49af/000007_color.jpg
# /home/yi/code/few_shot/mlt/box/14a10c1dd3b9e580b4d545c76c8d49af/000007.txt
# /media/yi/DATA/data-orig/MLT/depth/14a10c1dd3b9e580b4d545c76c8d49af/000007_depth.png
# 0.5352
# 0.5346528865947258
# /media/yi/DATA/data-orig/MLT/image/0004dd3cb11e50530676f77b55262d38/000004_color.jpg
# /home/yi/code/few_shot/mlt/box/0004dd3cb11e50530676f77b55262d38/000004.txt
# /media/yi/DATA/data-orig/MLT/depth/0004dd3cb11e50530676f77b55262d38/000004_depth.png
# 1.8286
# 1.6394024958491693
# 1.4206
# 1.1121761624891462
# 0.9688
# 0.9682549883391405
# /media/yi/DATA/data-orig/MLT/image/000e051cb512c617d32441a8a382b317/000007_color.jpg
# /home/yi/code/few_shot/mlt/box/000e051cb512c617d32441a8a382b317/000007.txt
# /media/yi/DATA/data-orig/MLT/depth/000e051cb512c617d32441a8a382b317/000007_depth.png
# 0.7228
# 0.7223725751161634
# 0.7798
# 0.7783724878853479
# /media/yi/DATA/data-orig/MLT/image/78468493df569514d83019efcb5a47ab/000020_color.jpg
# /home/yi/code/few_shot/mlt/box/78468493df569514d83019efcb5a47ab/000020.txt
# /media/yi/DATA/data-orig/MLT/depth/78468493df569514d83019efcb5a47ab/000020_depth.png
# 1.3962
# 1.3909368628820307
# /media/yi/DATA/data-orig/MLT/image/ef534daeb7898cfacfb75e269d7ef6f9/000003_color.jpg
# /home/yi/code/few_shot/mlt/box/ef534daeb7898cfacfb75e269d7ef6f9/000003.txt
# /media/yi/DATA/data-orig/MLT/depth/ef534daeb7898cfacfb75e269d7ef6f9/000003_depth.png
# 1.4612
# 1.4590557930396972
# 1.2286
# 1.2249286203246021
# 1.5564
# 1.5486056896656752
# /media/yi/DATA/data-orig/MLT/image/a3c9fc1a94d02f42f5ecf1c677f5206c/000047_color.jpg
# /home/yi/code/few_shot/mlt/box/a3c9fc1a94d02f42f5ecf1c677f5206c/000047.txt
# /media/yi/DATA/data-orig/MLT/depth/a3c9fc1a94d02f42f5ecf1c677f5206c/000047_depth.png
# 1.0928
# 1.0902574846425273
# 1.2804
# 1.2738315406300091
# 1.2804
# 1.2738300123917616
# 1.1908
# 1.177042599792249
# /media/yi/DATA/data-orig/MLT/image/b6367bf1a30592be07eaa1c2912f90fd/000001_color.jpg
# /home/yi/code/few_shot/mlt/box/b6367bf1a30592be07eaa1c2912f90fd/000001.txt
# /media/yi/DATA/data-orig/MLT/depth/b6367bf1a30592be07eaa1c2912f90fd/000001_depth.png
# 0.488
# 0.487257794199486
# 0.4828
# 0.48225084935436463
# /media/yi/DATA/data-orig/MLT/image/2464a538a0fd6e5d0a11f86289bed526/000004_color.jpg
# /home/yi/code/few_shot/mlt/box/2464a538a0fd6e5d0a11f86289bed526/000004.txt
# /media/yi/DATA/data-orig/MLT/depth/2464a538a0fd6e5d0a11f86289bed526/000004_depth.png
# 1.6784
# 1.6576713977650082
# 1.6784
# 1.662472798466589
# 1.3632
# 1.357849350643158
# /media/yi/DATA/data-orig/MLT/image/8b78c8c5d69b6aba079e2dcc18943598/000000_color.jpg
# /home/yi/code/few_shot/mlt/box/8b78c8c5d69b6aba079e2dcc18943598/000000.txt
# /media/yi/DATA/data-orig/MLT/depth/8b78c8c5d69b6aba079e2dcc18943598/000000_depth.png
# 1.14
# 1.1337473369917912
# 1.14
# 1.1344900881951572
# 1.1362
# 1.1274341931967888
# /media/yi/DATA/data-orig/MLT/image/7838af11cb685e598baecb35c8abd5b1/000031_color.jpg
# /home/yi/code/few_shot/mlt/box/7838af11cb685e598baecb35c8abd5b1/000031.txt
# /media/yi/DATA/data-orig/MLT/depth/7838af11cb685e598baecb35c8abd5b1/000031_depth.png
# 1.4162
# 1.377681373231135
# 2.0
# 1.5638
# 1.5625826501681357
# 0.8456
# 0.8392434514819853
# 0.8326
# 0.8262060683934677
# 0.5758
# 0.5752074196198276
# 1.7136
# 1.7030176507594827
# 1.0398
# 1.0386695791622054
# 1.7136
# 1.6950105159386948
# 1.7136
# 1.7075674536466598
# 0.8222
# 0.8127167797886843
# 0.621
# 0.6192130254481616
# 0.8304
# 0.8298809684875545
# 0.8304
# 0.8288570102458744
# 0.9168
# 0.9154888497515103
# 0.8948
# 0.8937849891172631
# 0.609
# 0.6085483699857406
# 0.6108
# 0.6107141483922844
# 1.4498
# 1.4425044038871584
# 1.1906
# 1.1871638803292468
# 1.1822
# 1.181635807309684
# 1.187
# 1.0089726400194312
# 1.0436
# 1.0427782169433255
# 1.099
# 1.0967095689202908
# 1.1058
# 1.1039234990491413
# 1.1058
# 1.1034534278984882
# 0.9552
# 0.9509910856364352
# 1.6778
# 1.0873729525450075
# 1.9978
# 1.2960300109145846
# 0.925
# 0.9204632085714219
# 1.0278
# 1.0132846689899593
# 1.373
# 1.3487113927155687
# 1.373
# 1.364107305951317
# 0.8086
# 0.8071846870399217
# 2.0
